# %% [markdown]
# # Models
#
# The following cells set up database tables for inserting and querying our eviction data.

# %%
from sqlalchemy import create_engine, UniqueConstraint
engine = create_engine('sqlite:///:memory:', echo=True)

# %%
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy import Column, Integer, String, ForeignKey, Table, Text
from sqlalchemy.orm import relationship

# %%
class District(Base):
    __tablename__ = 'districts'
    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    
    attorneys = relationship('Attorney', back_populates='district')
    plantiffs = relationship('Plantiff', back_populates='district')
    defendants = relationship('Defendant', back_populates='district')
    judges = relationship('Judge', back_populates='district')
    courtrooms = relationship('Courtroom', back_populates='district')
    
    def __repr__(self):
        return "<District(name='%s')>" % (self.name)

# %%
detainer_warrant_defendants = Table(
    'detainer_warrant_defendants', 
    Base.metadata,
    Column('detainer_warrant_docket_id', ForeignKey('detainer_warrants.docket_id'), primary_key=True),
    Column('defendant_id', ForeignKey('defendants.id'), primary_key=True)
)

# %%
class Defendant(Base):
    __tablename__ = 'defendants'
    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    phone = Column(String)
    address = Column(String, nullable=False)
    
    district_id = Column(Integer, ForeignKey('districts.id'), nullable=False)
    
    UniqueConstraint('name', 'district_id')
    
    district = relationship('District', back_populates='defendants')
    detainer_warrants = relationship('DetainerWarrant',
                                     secondary=detainer_warrant_defendants,
                                     back_populates='defendants'
                                    )

    def __repr__(self):
        return "<Defendant(name='%s', phone='%s', address='%s')>" % (self.name, self.phone, self.address)

# %%
class Attorney(Base):
    __tablename__ = 'attorneys'
    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    district_id = Column(Integer, ForeignKey('districts.id'), nullable=False)
    
    UniqueConstraint('name', 'district_id')
    
    district = relationship('District', back_populates='attorneys')
    plantiff_clients = relationship('Plantiff', back_populates='attorney')
    
    def __repr__(self):
        return "<Attorney(name='%s', district_id='%s')>" % (self.name, self.district_id)

# %%
class Courtroom(Base):
    __tablename__ = 'courtrooms'
    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    district_id = Column(Integer, ForeignKey('districts.id'), nullable=False)
    
    UniqueConstraint('name', 'district_id')
    
    district = relationship('District', back_populates='courtrooms')
    cases = relationship('DetainerWarrant', back_populates='courtroom')
    
    def __repr__(self):
        return "<Courtroom(name='%s')>" % (self.name)

# %%
class Plantiff(Base):
    __tablename__ = 'plantiffs'
    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    attorney_id = Column(Integer, ForeignKey('attorneys.id'))
    district_id = Column(Integer, ForeignKey('districts.id'), nullable=False)
    
    UniqueConstraint('name', 'district_id')
    
    district = relationship('District', back_populates='plantiffs')
    attorney = relationship('Attorney', back_populates='plantiff_clients')
    detainer_warrants = relationship('DetainerWarrant', back_populates='plantiff')
    
    def __repr__(self):
        return "<Plantiff(name='%s', attorney_id='%s', district_id='%s')>" % (self.name, self.attorney_id, self.district_id)

# %%
class Judge(Base):
    __tablename__ = "judges"
    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    district_id = Column(Integer, ForeignKey('districts.id'), nullable=False)
    
    UniqueConstraint('name', 'district_id')
    
    district = relationship('District', back_populates='judges')
    cases = relationship('DetainerWarrant', back_populates='presiding_judge')
    
    def __repr__(self):
        return "<Judge(name='%s')>" % (self.name)

# %%
class DetainerWarrant(Base):
    __tablename__ = 'detainer_warrants'
    docket_id = Column(String, primary_key=True)
    file_date = Column(String, nullable=False)
    status = Column(Integer, nullable=False) # union?
    plantiff_id = Column(Integer, ForeignKey('plantiffs.id'))
    court_date = Column(String, nullable=False) # date
    courtroom_id = Column(Integer, ForeignKey('courtrooms.id'), nullable=False)
    presiding_judge_id = Column(Integer, ForeignKey('judges.id'))
    amount_claimed = Column(String) # USD
    amount_claimed_category = Column(Integer, nullable=False) # enum (POSS | FEES | BOTH | NA)
    judgement = Column(Integer)
    judgement_notes = Column(String)
    
    plantiff = relationship('Plantiff', back_populates='detainer_warrants')
    courtroom = relationship('Courtroom', back_populates='cases')
    presiding_judge = relationship('Judge', back_populates='cases')
    
    defendants = relationship('Defendant',
                              secondary=detainer_warrant_defendants,
                              back_populates='detainer_warrants'
                             )
    def __repr__(self):
        return "<DetainerWarrant(docket_id='%s', file_date='%s')>" % (self.docket_id, self.file_date)

# %%
Base.metadata.create_all(engine)
# Out:
# 2021-02-23 06:02:22,039 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 06:02:22,041 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,042 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-02-23 06:02:22,043 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,044 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("districts")
# 2021-02-23 06:02:22,045 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,047 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("districts")
# 2021-02-23 06:02:22,049 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,050 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("detainer_warrant_defendants")
# 2021-02-23 06:02:22,051 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,052 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("detainer_warrant_defendants")
# 2021-02-23 06:02:22,053 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,054 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("defendants")
# 2021-02-23 06:02:22,055 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,056 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("defendants")
# 2021-02-23 06:02:22,057 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,058 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("attorneys")
# 2021-02-23 06:02:22,059 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,059 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("attorneys")
# 2021-02-23 06:02:22,060 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,062 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("courtrooms")
# 2021-02-23 06:02:22,063 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,066 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("courtrooms")
# 2021-02-23 06:02:22,067 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,068 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("plantiffs")
# 2021-02-23 06:02:22,068 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,069 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("plantiffs")
# 2021-02-23 06:02:22,070 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,071 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("judges")
# 2021-02-23 06:02:22,072 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,074 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("judges")
# 2021-02-23 06:02:22,075 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,076 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("detainer_warrants")
# 2021-02-23 06:02:22,076 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,078 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("detainer_warrants")
# 2021-02-23 06:02:22,079 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,082 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE districts (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-02-23 06:02:22,083 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,084 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:22,085 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE defendants (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	phone VARCHAR,
# 	address VARCHAR NOT NULL,
# 	district_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(district_id) REFERENCES districts (id)
# )
#
#
# 2021-02-23 06:02:22,086 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,087 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:22,088 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE attorneys (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	district_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(district_id) REFERENCES districts (id)
# )
#
#
# 2021-02-23 06:02:22,089 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,090 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:22,091 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE courtrooms (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	district_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(district_id) REFERENCES districts (id)
# )
#
#
# 2021-02-23 06:02:22,092 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,093 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:22,095 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE judges (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	district_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(district_id) REFERENCES districts (id)
# )
#
#
# 2021-02-23 06:02:22,097 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,099 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:22,101 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE plantiffs (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	attorney_id INTEGER,
# 	district_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(attorney_id) REFERENCES attorneys (id),
# 	FOREIGN KEY(district_id) REFERENCES districts (id)
# )
#
#
# 2021-02-23 06:02:22,102 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,104 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:22,106 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE detainer_warrants (
# 	docket_id VARCHAR NOT NULL,
# 	file_date VARCHAR NOT NULL,
# 	status INTEGER NOT NULL,
# 	plantiff_id INTEGER,
# 	court_date VARCHAR NOT NULL,
# 	courtroom_id INTEGER NOT NULL,
# 	presiding_judge_id INTEGER,
# 	amount_claimed VARCHAR,
# 	amount_claimed_category INTEGER NOT NULL,
# 	judgement INTEGER,
# 	judgement_notes VARCHAR,
# 	PRIMARY KEY (docket_id),
# 	FOREIGN KEY(plantiff_id) REFERENCES plantiffs (id),
# 	FOREIGN KEY(courtroom_id) REFERENCES courtrooms (id),
# 	FOREIGN KEY(presiding_judge_id) REFERENCES judges (id)
# )
#
#
# 2021-02-23 06:02:22,108 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,110 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:22,111 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE detainer_warrant_defendants (
# 	detainer_warrant_docket_id VARCHAR NOT NULL,
# 	defendant_id INTEGER NOT NULL,
# 	PRIMARY KEY (detainer_warrant_docket_id, defendant_id),
# 	FOREIGN KEY(detainer_warrant_docket_id) REFERENCES detainer_warrants (docket_id),
# 	FOREIGN KEY(defendant_id) REFERENCES defendants (id)
# )
#
#
# 2021-02-23 06:02:22,112 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-23 06:02:22,114 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# # Spreadsheet Data
#
# We'll be grabbing spreadsheet data from Google here, using the gspread library.

# %%
import gspread
gc = gspread.service_account()
sh = gc.open('detainer-warrants_15-02-2020')
ws = sh.worksheet("All Detainer Warrants")

# %%
ws.row_values(1)
# Out:
# ['Docket #',
#  'Order #',
#  'File Date',
#  'Status',
#  'Month',
#  'Year',
#  'Plantiff',
#  'Pltf. Attorney',
#  'Court Date',
#  'Courtroom',
#  'Presiding Judge',
#  'Amt Claimed ($)',
#  'Amount Claimed (CATEGORY)',
#  'Amount Claimed (NON-$)',
#  'Defendant(s)',
#  'Defendant Address',
#  'Def #1 Name',
#  'Def #1 Phone',
#  'Def #2 Name',
#  'Def #2 Phone',
#  'Def #3 Name',
#  'Def #3 Phone',
#  'Judgement']

# %%
warrant = ws.row_values(3)

# %%
from sqlalchemy.orm import sessionmaker

# %%
Session = sessionmaker(bind=engine)
Session.configure(bind=engine)
session = Session()

# %%
def init_status(warrant):
    statuses = {
        'CLOSED': 0,
        'PENDING': 1
    }
    return statuses[warrant[3].upper()]

# %%
def init_amount_claimed_category(warrant):
    categories = {
        'POSS': 0,
        'FEES': 1,
        'BOTH': 2,
        'N/A': 3,
        '': 4
    }
    return categories[warrant[12].upper()]

# %%
def init_judgement(warrant):
    judgements = {} # TODO: work on this
    return judgements[warrant[20]]

# %%
from sqlalchemy.sql import ClauseElement

def get_or_create(session, model, defaults=None, **kwargs):
    instance = session.query(model).filter_by(**kwargs).one_or_none()
    if instance:
        return instance, False
    else:
        params = {k: v for k, v in kwargs.items() if not isinstance(v, ClauseElement)}
        params.update(defaults or {})
        instance = model(**params)
        try:
            session.add(instance)
            session.commit()
        except Exception:  # The actual exception depends on the specific database so we catch all exceptions. This is similar to the official documentation: https://docs.sqlalchemy.org/en/latest/orm/session_transaction.html
            session.rollback()
            instance = session.query(model).filter_by(**kwargs).one()
            return instance, False
        else:
            return instance, True

# %%
district = District(name="Davidson County")

session.add(district)
session.commit()
# Out:
# 2021-02-23 06:02:24,884 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:24,886 INFO sqlalchemy.engine.base.Engine INSERT INTO districts (name) VALUES (?)
# 2021-02-23 06:02:24,887 INFO sqlalchemy.engine.base.Engine ('Davidson County',)
# 2021-02-23 06:02:24,890 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
defaults = {'district': district}

def detainer_warrant(warrant):
    docket_id = warrant[0]
    file_date = warrant[2]
    status = init_status(warrant)
    attorney, _ = get_or_create(session, Attorney, name=warrant[7], defaults=defaults)
    plantiff, _ = get_or_create(session, Plantiff, name=warrant[6], attorney=attorney, defaults=defaults)
    court_date = warrant[8]
    courtroom, _ = get_or_create(session, Courtroom, name=warrant[9], defaults=defaults)
    presiding_judge, _ = get_or_create(session, Judge, name=warrant[10], defaults=defaults)
    amount_claimed = warrant[11]
    amount_claimed_category = init_amount_claimed_category(warrant)
    defendant, _ = get_or_create(session, Defendant, address=warrant[15], name=warrant[14], phone=warrant[16], defaults=defaults)
    
    return DetainerWarrant(
        docket_id=docket_id,
        file_date=file_date,
        status=status,
        plantiff=plantiff,
        court_date=court_date,
        courtroom=courtroom,
        presiding_judge=presiding_judge,
        amount_claimed=amount_claimed,
        amount_claimed_category=amount_claimed_category,
        defendants=[defendant]
        )

# %%
NUM_WARRANTS_TO_INSERT = 5 # insert just a bit of data to play with

for warrant in ws.get_all_values()[1:NUM_WARRANTS_TO_INSERT]:
    session.add(detainer_warrant(warrant))

session.commit()
# Out:
# 2021-02-23 06:02:25,910 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:25,911 INFO sqlalchemy.engine.base.Engine SELECT attorneys.id AS attorneys_id, attorneys.name AS attorneys_name, attorneys.district_id AS attorneys_district_id
# FROM attorneys
# WHERE attorneys.name = ?
# 2021-02-23 06:02:25,912 INFO sqlalchemy.engine.base.Engine ('PRS',)
# 2021-02-23 06:02:25,914 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:25,914 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,916 INFO sqlalchemy.engine.base.Engine INSERT INTO attorneys (name, district_id) VALUES (?, ?)
# 2021-02-23 06:02:25,917 INFO sqlalchemy.engine.base.Engine ('PRS', 1)
# 2021-02-23 06:02:25,918 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:25,919 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:25,921 INFO sqlalchemy.engine.base.Engine SELECT attorneys.id AS attorneys_id, attorneys.name AS attorneys_name, attorneys.district_id AS attorneys_district_id
# FROM attorneys
# WHERE attorneys.id = ?
# 2021-02-23 06:02:25,922 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,923 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.name = ? AND ? = plantiffs.attorney_id
# 2021-02-23 06:02:25,924 INFO sqlalchemy.engine.base.Engine ('DADE,SONDRA A', 1)
# 2021-02-23 06:02:25,926 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:25,927 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,928 INFO sqlalchemy.engine.base.Engine INSERT INTO plantiffs (name, attorney_id, district_id) VALUES (?, ?, ?)
# 2021-02-23 06:02:25,929 INFO sqlalchemy.engine.base.Engine ('DADE,SONDRA A', 1, 1)
# 2021-02-23 06:02:25,930 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:25,932 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:25,933 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.name = ?
# 2021-02-23 06:02:25,934 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:25,936 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:25,937 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,939 INFO sqlalchemy.engine.base.Engine INSERT INTO courtrooms (name, district_id) VALUES (?, ?)
# 2021-02-23 06:02:25,940 INFO sqlalchemy.engine.base.Engine ('', 1)
# 2021-02-23 06:02:25,941 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:25,943 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:25,944 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.name = ?
# 2021-02-23 06:02:25,945 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:25,948 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:25,949 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,951 INFO sqlalchemy.engine.base.Engine INSERT INTO judges (name, district_id) VALUES (?, ?)
# 2021-02-23 06:02:25,952 INFO sqlalchemy.engine.base.Engine ('', 1)
# 2021-02-23 06:02:25,953 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:25,955 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:25,957 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.address = ? AND defendants.name = ? AND defendants.phone = ?
# 2021-02-23 06:02:25,958 INFO sqlalchemy.engine.base.Engine ('741 LONGHUNTER COURT 37217', 'CROWE,JARED', 'JARED CROWE')
# 2021-02-23 06:02:25,960 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:25,960 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,962 INFO sqlalchemy.engine.base.Engine INSERT INTO defendants (name, phone, address, district_id) VALUES (?, ?, ?, ?)
# 2021-02-23 06:02:25,963 INFO sqlalchemy.engine.base.Engine ('CROWE,JARED', 'JARED CROWE', '741 LONGHUNTER COURT 37217', 1)
# 2021-02-23 06:02:25,965 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:25,967 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:25,969 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.id = ?
# 2021-02-23 06:02:25,970 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,972 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.id = ?
# 2021-02-23 06:02:25,972 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,974 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.id = ?
# 2021-02-23 06:02:25,975 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,976 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrants (docket_id, file_date, status, plantiff_id, court_date, courtroom_id, presiding_judge_id, amount_claimed, amount_claimed_category, judgement, judgement_notes) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 06:02:25,977 INFO sqlalchemy.engine.base.Engine ('20GT1', '1/2/20', 0, 1, '', 1, 1, '', 4, None, None)
# 2021-02-23 06:02:25,980 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.id = ?
# 2021-02-23 06:02:25,981 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,983 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrant_defendants (detainer_warrant_docket_id, defendant_id) VALUES (?, ?)
# 2021-02-23 06:02:25,984 INFO sqlalchemy.engine.base.Engine ('20GT1', 1)
# 2021-02-23 06:02:25,986 INFO sqlalchemy.engine.base.Engine SELECT attorneys.id AS attorneys_id, attorneys.name AS attorneys_name, attorneys.district_id AS attorneys_district_id
# FROM attorneys
# WHERE attorneys.name = ?
# 2021-02-23 06:02:25,987 INFO sqlalchemy.engine.base.Engine ('PRS',)
# 2021-02-23 06:02:25,989 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.name = ? AND ? = plantiffs.attorney_id
# 2021-02-23 06:02:25,990 INFO sqlalchemy.engine.base.Engine ('BATTLE,PATRICIA', 1)
# 2021-02-23 06:02:25,992 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:25,992 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:25,993 INFO sqlalchemy.engine.base.Engine INSERT INTO plantiffs (name, attorney_id, district_id) VALUES (?, ?, ?)
# 2021-02-23 06:02:25,994 INFO sqlalchemy.engine.base.Engine ('BATTLE,PATRICIA', 1, 1)
# 2021-02-23 06:02:25,995 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:25,997 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:25,998 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.name = ?
# 2021-02-23 06:02:25,999 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:26,001 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.name = ?
# 2021-02-23 06:02:26,002 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:26,005 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.address = ? AND defendants.name = ? AND defendants.phone = ?
# 2021-02-23 06:02:26,006 INFO sqlalchemy.engine.base.Engine ('5109 BUENA VISTA PIKE 37218', 'WILLIAMS,SHARHONDA', 'SHARHONDA WILLIAMS')
# 2021-02-23 06:02:26,007 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:26,008 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,009 INFO sqlalchemy.engine.base.Engine INSERT INTO defendants (name, phone, address, district_id) VALUES (?, ?, ?, ?)
# 2021-02-23 06:02:26,010 INFO sqlalchemy.engine.base.Engine ('WILLIAMS,SHARHONDA', 'SHARHONDA WILLIAMS', '5109 BUENA VISTA PIKE 37218', 1)
# 2021-02-23 06:02:26,011 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:26,014 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:26,015 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.id = ?
# 2021-02-23 06:02:26,016 INFO sqlalchemy.engine.base.Engine (2,)
# 2021-02-23 06:02:26,018 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.id = ?
# 2021-02-23 06:02:26,018 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,020 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.id = ?
# 2021-02-23 06:02:26,021 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,022 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrants (docket_id, file_date, status, plantiff_id, court_date, courtroom_id, presiding_judge_id, amount_claimed, amount_claimed_category, judgement, judgement_notes) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 06:02:26,024 INFO sqlalchemy.engine.base.Engine ('20GT2', '1/2/20', 0, 2, '', 1, 1, '', 4, None, None)
# 2021-02-23 06:02:26,025 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.id = ?
# 2021-02-23 06:02:26,026 INFO sqlalchemy.engine.base.Engine (2,)
# 2021-02-23 06:02:26,027 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrant_defendants (detainer_warrant_docket_id, defendant_id) VALUES (?, ?)
# 2021-02-23 06:02:26,028 INFO sqlalchemy.engine.base.Engine ('20GT2', 2)
# 2021-02-23 06:02:26,029 INFO sqlalchemy.engine.base.Engine SELECT attorneys.id AS attorneys_id, attorneys.name AS attorneys_name, attorneys.district_id AS attorneys_district_id
# FROM attorneys
# WHERE attorneys.name = ?
# 2021-02-23 06:02:26,030 INFO sqlalchemy.engine.base.Engine ('PRS',)
# 2021-02-23 06:02:26,032 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.name = ? AND ? = plantiffs.attorney_id
# 2021-02-23 06:02:26,034 INFO sqlalchemy.engine.base.Engine ('DELGADO,PABLO', 1)
# 2021-02-23 06:02:26,037 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:26,038 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,040 INFO sqlalchemy.engine.base.Engine INSERT INTO plantiffs (name, attorney_id, district_id) VALUES (?, ?, ?)
# 2021-02-23 06:02:26,040 INFO sqlalchemy.engine.base.Engine ('DELGADO,PABLO', 1, 1)
# 2021-02-23 06:02:26,041 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:26,043 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:26,044 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.name = ?
# 2021-02-23 06:02:26,044 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:26,046 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.name = ?
# 2021-02-23 06:02:26,047 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:26,049 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.address = ? AND defendants.name = ? AND defendants.phone = ?
# 2021-02-23 06:02:26,050 INFO sqlalchemy.engine.base.Engine ('323 FOREST PARK RD BLD 6 APT 2 37115', 'OCCUPANT', ' OCCUPANT')
# 2021-02-23 06:02:26,052 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:26,053 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,054 INFO sqlalchemy.engine.base.Engine INSERT INTO defendants (name, phone, address, district_id) VALUES (?, ?, ?, ?)
# 2021-02-23 06:02:26,055 INFO sqlalchemy.engine.base.Engine ('OCCUPANT', ' OCCUPANT', '323 FOREST PARK RD BLD 6 APT 2 37115', 1)
# 2021-02-23 06:02:26,056 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:26,059 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:26,060 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.id = ?
# 2021-02-23 06:02:26,061 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,063 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.id = ?
# 2021-02-23 06:02:26,064 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,065 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.id = ?
# 2021-02-23 06:02:26,066 INFO sqlalchemy.engine.base.Engine (3,)
# 2021-02-23 06:02:26,067 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrants (docket_id, file_date, status, plantiff_id, court_date, courtroom_id, presiding_judge_id, amount_claimed, amount_claimed_category, judgement, judgement_notes) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 06:02:26,068 INFO sqlalchemy.engine.base.Engine ('20GT3', '1/2/20', 0, 3, '', 1, 1, '', 4, None, None)
# 2021-02-23 06:02:26,069 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.id = ?
# 2021-02-23 06:02:26,070 INFO sqlalchemy.engine.base.Engine (3,)
# 2021-02-23 06:02:26,071 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrant_defendants (detainer_warrant_docket_id, defendant_id) VALUES (?, ?)
# 2021-02-23 06:02:26,072 INFO sqlalchemy.engine.base.Engine ('20GT3', 3)
# 2021-02-23 06:02:26,074 INFO sqlalchemy.engine.base.Engine SELECT attorneys.id AS attorneys_id, attorneys.name AS attorneys_name, attorneys.district_id AS attorneys_district_id
# FROM attorneys
# WHERE attorneys.name = ?
# 2021-02-23 06:02:26,074 INFO sqlalchemy.engine.base.Engine ('PRS',)
# 2021-02-23 06:02:26,076 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.name = ? AND ? = plantiffs.attorney_id
# 2021-02-23 06:02:26,077 INFO sqlalchemy.engine.base.Engine ('JERNIGAN,JERRY D', 1)
# 2021-02-23 06:02:26,079 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:26,080 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,082 INFO sqlalchemy.engine.base.Engine INSERT INTO plantiffs (name, attorney_id, district_id) VALUES (?, ?, ?)
# 2021-02-23 06:02:26,082 INFO sqlalchemy.engine.base.Engine ('JERNIGAN,JERRY D', 1, 1)
# 2021-02-23 06:02:26,083 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:26,085 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:26,086 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.name = ?
# 2021-02-23 06:02:26,087 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:26,089 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.name = ?
# 2021-02-23 06:02:26,090 INFO sqlalchemy.engine.base.Engine ('',)
# 2021-02-23 06:02:26,091 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.address = ? AND defendants.name = ? AND defendants.phone = ?
# 2021-02-23 06:02:26,092 INFO sqlalchemy.engine.base.Engine ('2925 CHAPELWOOD DR 37076', 'SCHUTT,MICHAEL  ', 'MICHAEL SCHUTT')
# 2021-02-23 06:02:26,094 INFO sqlalchemy.engine.base.Engine SELECT districts.id AS districts_id, districts.name AS districts_name
# FROM districts
# WHERE districts.id = ?
# 2021-02-23 06:02:26,095 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,096 INFO sqlalchemy.engine.base.Engine INSERT INTO defendants (name, phone, address, district_id) VALUES (?, ?, ?, ?)
# 2021-02-23 06:02:26,097 INFO sqlalchemy.engine.base.Engine ('SCHUTT,MICHAEL  ', 'MICHAEL SCHUTT', '2925 CHAPELWOOD DR 37076', 1)
# 2021-02-23 06:02:26,098 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-02-23 06:02:26,100 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:26,102 INFO sqlalchemy.engine.base.Engine SELECT judges.id AS judges_id, judges.name AS judges_name, judges.district_id AS judges_district_id
# FROM judges
# WHERE judges.id = ?
# 2021-02-23 06:02:26,103 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,104 INFO sqlalchemy.engine.base.Engine SELECT courtrooms.id AS courtrooms_id, courtrooms.name AS courtrooms_name, courtrooms.district_id AS courtrooms_district_id
# FROM courtrooms
# WHERE courtrooms.id = ?
# 2021-02-23 06:02:26,105 INFO sqlalchemy.engine.base.Engine (1,)
# 2021-02-23 06:02:26,107 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE plantiffs.id = ?
# 2021-02-23 06:02:26,107 INFO sqlalchemy.engine.base.Engine (4,)
# 2021-02-23 06:02:26,109 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrants (docket_id, file_date, status, plantiff_id, court_date, courtroom_id, presiding_judge_id, amount_claimed, amount_claimed_category, judgement, judgement_notes) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-02-23 06:02:26,109 INFO sqlalchemy.engine.base.Engine ('20GT4', '1/2/20', 0, 4, '', 1, 1, '', 4, None, None)
# 2021-02-23 06:02:26,111 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants
# WHERE defendants.id = ?
# 2021-02-23 06:02:26,112 INFO sqlalchemy.engine.base.Engine (4,)
# 2021-02-23 06:02:26,113 INFO sqlalchemy.engine.base.Engine INSERT INTO detainer_warrant_defendants (detainer_warrant_docket_id, defendant_id) VALUES (?, ?)
# 2021-02-23 06:02:26,114 INFO sqlalchemy.engine.base.Engine ('20GT4', 4)
# 2021-02-23 06:02:26,115 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# ## Querying the database
#
# Refer to the SQLAlchemy [official querying documentation](https://docs.sqlalchemy.org/en/13/orm/tutorial.html#querying).
# This reference will be invaluable for learning how to work with this data.
#
# Below are some example queries:

# %%
session.query(DetainerWarrant).first().defendants
# Out:
# 2021-02-23 06:02:26,123 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-23 06:02:26,125 INFO sqlalchemy.engine.base.Engine SELECT detainer_warrants.docket_id AS detainer_warrants_docket_id, detainer_warrants.file_date AS detainer_warrants_file_date, detainer_warrants.status AS detainer_warrants_status, detainer_warrants.plantiff_id AS detainer_warrants_plantiff_id, detainer_warrants.court_date AS detainer_warrants_court_date, detainer_warrants.courtroom_id AS detainer_warrants_courtroom_id, detainer_warrants.presiding_judge_id AS detainer_warrants_presiding_judge_id, detainer_warrants.amount_claimed AS detainer_warrants_amount_claimed, detainer_warrants.amount_claimed_category AS detainer_warrants_amount_claimed_category, detainer_warrants.judgement AS detainer_warrants_judgement, detainer_warrants.judgement_notes AS detainer_warrants_judgement_notes
# FROM detainer_warrants
#  LIMIT ? OFFSET ?
# 2021-02-23 06:02:26,126 INFO sqlalchemy.engine.base.Engine (1, 0)
# 2021-02-23 06:02:26,128 INFO sqlalchemy.engine.base.Engine SELECT defendants.id AS defendants_id, defendants.name AS defendants_name, defendants.phone AS defendants_phone, defendants.address AS defendants_address, defendants.district_id AS defendants_district_id
# FROM defendants, detainer_warrant_defendants
# WHERE ? = detainer_warrant_defendants.detainer_warrant_docket_id AND defendants.id = detainer_warrant_defendants.defendant_id
# 2021-02-23 06:02:26,129 INFO sqlalchemy.engine.base.Engine ('20GT1',)
# [<Defendant(name='CROWE,JARED', phone='JARED CROWE', address='741 LONGHUNTER COURT 37217')>]

# %%
session.query(Attorney).first().plantiff_clients
# Out:
# 2021-02-23 06:02:26,139 INFO sqlalchemy.engine.base.Engine SELECT attorneys.id AS attorneys_id, attorneys.name AS attorneys_name, attorneys.district_id AS attorneys_district_id
# FROM attorneys
#  LIMIT ? OFFSET ?
# 2021-02-23 06:02:26,140 INFO sqlalchemy.engine.base.Engine (1, 0)
# 2021-02-23 06:02:26,143 INFO sqlalchemy.engine.base.Engine SELECT plantiffs.id AS plantiffs_id, plantiffs.name AS plantiffs_name, plantiffs.attorney_id AS plantiffs_attorney_id, plantiffs.district_id AS plantiffs_district_id
# FROM plantiffs
# WHERE ? = plantiffs.attorney_id
# 2021-02-23 06:02:26,144 INFO sqlalchemy.engine.base.Engine (1,)
# [<Plantiff(name='DADE,SONDRA A', attorney_id='1', district_id='1')>,
#  <Plantiff(name='BATTLE,PATRICIA', attorney_id='1', district_id='1')>,
#  <Plantiff(name='DELGADO,PABLO', attorney_id='1', district_id='1')>,
#  <Plantiff(name='JERNIGAN,JERRY D', attorney_id='1', district_id='1')>]
